# %% [markdown]
# 開發AGI的挑戰之一是賦予系統以我們人類認為理所當然的關於世界的常識性知識的推理能力。這裡我們用
# 幾個例子來證明GPT-4有常識基礎。特別是，我們將GPT-4與ChatGPT自始至終進行了比較，以展示GPT-4
# 與它的前輩相比在常識水平上的巨大飛躍。測試人工智能係統的常識知識的一種方法是提出需要對世界有一
# 些基本了解的謎題

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
